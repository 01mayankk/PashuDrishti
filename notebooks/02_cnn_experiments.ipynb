# %% [markdown]
# # CNN Experiments
#
# This notebook contains experiments with different CNN architectures.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('../src')))

from models.train_cnn import create_cnn_model, train_model
from utils.config import load_config

# %%
# Load configuration
config = load_config()
print(config)

# %%
# Train model
# model, history = train_model(config)
